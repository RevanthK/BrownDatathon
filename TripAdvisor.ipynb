# %%
import csv
import pandas as pd

# %%
act_data = pd.read_csv("activity_data.csv")
act_data
# Out:
#                date  user_id    user_country              device  hotel_id  \
# 0        2019-01-07   314066           Italy   iphone_native_app    570101
# 1        2019-01-02   314066           Italy   iphone_native_app   6002536
# 2        2019-01-19    84981  United Kingdom   iphone_native_app   1858923
# 3        2019-01-19    84981  United Kingdom   iphone_native_app   3580899
# 4        2019-01-19    84981  United Kingdom   iphone_native_app    277882
# 5        2019-01-19    84981  United Kingdom   iphone_native_app  12297961
# 6        2019-01-21   268141   United States   iphone_native_app   2079052
# 7        2019-01-03   268141   United States   iphone_native_app   3235844
# 8        2019-01-05   268141   United States   iphone_native_app    601762
# 9        2019-01-04   268141   United States   iphone_native_app   3235844
# 10       2019-01-04   268141   United States   iphone_native_app   3235844
# ...

# %%
hotel_data = pd.read_csv("hotel_data.csv")
hotel_data
# Out:
#       hotel_id                                         hotel_name  \
# 0        75737                             Night Theater District
# 1        93401                       Heritage Hotel New York City
# 2       224217                          Clarion Hotel Park Avenue
# 3       488793                                  Solita Soho Hotel
# 4      1028569                                    Greenwich Hotel
# 5      1383001                       Comfort Inn Manhattan Bridge
# 6      1733337                      Sutton Court Hotel Residences
# 7      1776857                  The Langham New York Fifth Avenue
# 8      2643161                           The NoMad Hotel New York
# 9      7148761                           Cassa Hotel Times Square
# 10     7379289                     Brooklyn Hostel - Utica Avenue
# 11     8541913                 Renaissance New York Midtown Hotel
# 12     9608281                                         Sago Hotel
# ...

# %%
combined_data= pd.merge(act_data, hotel_data, on= 'hotel_id')
combined_data
# Out:
#                date  user_id     user_country                  device  \
# 0        2019-01-07   314066            Italy       iphone_native_app
# 1        2019-01-14   229655          Germany                 windows
# 2        2019-01-20   135830          Germany                 windows
# 3        2019-01-08   222524    United States                 windows
# 4        2019-01-10    51835   United Kingdom          iphone_browser
# 5        2019-01-17   272885    United States       iphone_native_app
# 6        2019-01-08   159082           Brazil                 windows
# 7        2019-01-21   303987           Brazil         android_browser
# 8        2019-01-19   213139           Kuwait                 windows
# 9        2019-01-27   314463    United States          iphone_browser
# 10       2019-01-18   127583    United States                   other
# 11       2019-01-15   181546           France                 windows
# ...
